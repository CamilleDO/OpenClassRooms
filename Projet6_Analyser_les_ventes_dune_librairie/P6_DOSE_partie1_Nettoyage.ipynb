# %% [markdown]
# <div style="display: flex; text-align:center; background-color: rgb(153,102,153);" >
# <h1 style="margin: auto; padding: 30px; ">Analysez les ventes d'une librairie avec Python <br>
# </h1>

# %% [markdown]
# <div style="display: flex; text-align:center; background-color: rgb(153,102,153);" >
# <h1 style="margin: auto; padding: 30px; ">Partie 1 - Nettoyage <br></h1>

# %% [markdown]
# # Scénario

# %% [markdown]
# Je suis consultant Data Analyst chez Lapage, une librairie généraliste réputée, qui fait de la vente en ligne depuis 2 ans.
#
# Je suis ratachée au service Marketing
#
# Mes missions :
#
#  - Analyse des indicateurs de vente
#  - Analyse des comportements clients en ligne pour les comparer à la vente des librairies physiques.

# %% [markdown]
#  <div style="background-color: RGB(51,165,182);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">1 - Importation des librairies et fichiers</h2>

# %%
import pandas as pd
import numpy as np
import datetime as datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv("customers.csv")
products = pd.read_csv("products.csv")
transactions = pd.read_csv("transactions.csv")

# %% [markdown]
# <div style="background-color: RGB(51,165,182);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">2 - Nettoyage </h2>

# %% [markdown]
# Méthodologie :
# - Premier visuel : head(), shape, dtypes...
# - Validation des PK : nunique()...
# - Recherche erreur de valeur : unique(), min(), max()...
# - Recherche et modification des doublons : duplicated()...
# - Recherche et modification des valeurs manquantes : isna(), fillna()...

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 10px; color: RGB(51,165,182); ">2.1- customers </h3>

# %%
customers.head()
# Out:
#   client_id sex  birth
# 0    c_4410   f   1967
# 1    c_7839   f   1975
# 2    c_1699   f   1984
# 3    c_5961   f   1962
# 4    c_5320   m   1943

# %%
print(customers.shape)
print(customers.dtypes)
# Out:
# (8623, 3)
# client_id    object
# sex          object
# birth         int64
# dtype: object

# %%
#Vérif PK --> client_id
print(customers['client_id'].nunique())
print(customers['client_id'].nunique() == customers.shape[0])
# Out:
# 8623
# True

# %% [markdown]
# ## Nettoyage

# %%
print(customers['client_id'].duplicated().sum())
print(customers.isna().sum())
# Out:
# 0
# client_id    0
# sex          0
# birth        0
# dtype: int64

# %%
customers['sex'].value_counts()
# Out:
# f    4491
# m    4132
# Name: sex, dtype: int64

# %%
# Les clients les plus âgés = 93 ans et les moins âgés = 18 ans
customers.groupby('birth')['client_id'].count()
# Out:
# birth
# 1929      3
# 1930      4
# 1931      4
# 1932      6
# 1933      8
#        ...
# 2000    136
# 2001    129
# 2002    146
# 2003    146
# 2004    440
# Name: client_id, Length: 76, dtype: int64

# %%
customers['client_id'].unique().tolist()
# Out:
# ['c_4410',
#  'c_7839',
#  'c_1699',
#  'c_5961',
#  'c_5320',
#  'c_415',
#  'c_285',
#  'c_160',
#  'c_6446',
#  'c_6866',
#  'c_1013',
#  'c_4389',
#  'c_1375',
#  'c_2998',
#  'c_2322',
#  'c_4701',
#  'c_8203',
#  'c_5019',
#  'c_6616',
#  'c_7049',
#  'c_4710',
#  'c_7900',
#  'c_6245',
#  'c_4279',
#  'c_3692',
#  'c_1361',
#  'c_2487',
#  'c_6884',
#  'c_1466',
#  'c_3213',
#  'c_5152',
#  'c_539',
#  'c_4799',
#  'c_1685',
#  'c_3001',
#  'c_7548',
#  'c_3654',
#  'c_459',
#  'c_3991',
#  'c_3477',
#  'c_5361',
#  'c_125',
#  'c_4313',
#  'c_1046',
#  'c_5633',
#  'c_169',
#  'c_1303',
#  'c_329',
#  'c_3473',
#  'c_3424',
#  'c_2098',
#  'c_8413',
#  'c_4223',
#  'c_1136',
#  'c_5110',
#  'c_3023',
#  'c_7675',
#  'c_6071',
#  'c_344',
#  'c_7384',
#  'c_3512',
#  'c_6699',
#  'c_2167',
#  'c_2253',
#  'c_5139',
#  'c_5138',
#  'c_7255',
#  'c_4575',
#  'c_6673',
#  'c_3060',
#  'c_3662',
#  'c_3081',
#  'c_7391',
#  'c_3710',
#  'c_5422',
#  'c_651',
#  'c_3598',
#  'c_939',
#  'c_1783',
#  'c_5050',
#  'c_5445',
#  'c_6809',
#  'c_8349',
#  'c_3196',
#  'c_4505',
#  'c_181',
#  'c_7921',
#  'c_7946',
#  'c_6312',
#  'c_1615',
#  'c_4767',
#  'c_4398',
#  'c_3468',
#  'c_6208',
#  'c_997',
#  'c_1418',
#  'c_1953',
#  'c_3824',
#  'c_1821',
#  'c_7249',
#  'c_198',
#  'c_3338',
#  'c_420',
#  'c_3550',
#  'c_4020',
#  'c_4662',
#  'c_1774',
#  'c_3939',
#  'c_8278',
#  'c_8357',
#  'c_4134',
#  'c_5113',
#  'c_6829',
#  'c_6881',
#  'c_4271',
#  'c_5758',
#  'c_2384',
#  'c_6276',
#  'c_3170',
#  'c_1934',
#  'c_2123',
#  'c_6994',
#  'c_8083',
#  'c_5544',
#  'c_6822',
#  'c_7222',
#  'c_7758',
#  'c_3247',
#  'c_1721',
#  'c_2666',
#  'c_2124',
#  'c_1199',
#  'c_4472',
#  'c_4430',
#  'c_4882',
#  'c_2611',
#  'c_2005',
#  'c_3366',
#  'c_7944',
#  'c_1044',
#  'c_488',
#  'c_7857',
#  'c_4683',
#  'c_7718',
#  'c_5059',
#  'c_6845',
#  'c_2311',
#  'c_7200',
#  'c_5214',
#  'c_4207',
#  'c_6468',
#  'c_2510',
#  'c_1499',
#  'c_7441',
#  'c_2402',
#  'c_6105',
#  'c_4978',
#  'c_1239',
#  'c_6060',
#  'c_1958',
#  'c_3167',
#  'c_6917',
#  'c_6534',
#  'c_8564',
#  'c_2120',
#  'c_7890',
#  'c_4755',
#  'c_1836',
#  'c_6889',
#  'c_3572',
#  'c_5080',
#  'c_5146',
#  'c_1320',
#  'c_712',
#  'c_8395',
#  'c_1381',
#  'c_858',
#  'c_7193',
#  'c_1859',
#  'c_8384',
#  'c_3568',
#  'c_1033',
#  'c_3041',
#  'c_178',
#  'c_3746',
#  'c_3601',
#  'c_6754',
#  'c_1561',
#  'c_4087',
#  'c_5898',
#  'c_7755',
#  'c_6950',
#  'c_7680',
#  'c_7046',
#  'c_3413',
#  'c_626',
#  'c_5810',
#  'c_4325',
#  'c_1403',
#  'c_2276',
#  'c_1531',
#  'c_4694',
#  'c_4512',
#  'c_7075',
#  'c_2696',
#  'c_6179',
#  'c_2714',
#  'c_1216',
#  'c_8506',
#  'c_7866',
#  'c_2809',
#  'c_955',
#  'c_424',
#  'c_5843',
#  'c_7134',
#  'c_2352',
#  'c_3244',
#  'c_5752',
#  'c_7795',
#  'c_457',
#  'c_2669',
#  'c_4423',
#  'c_4917',
#  'c_5521',
#  'c_8105',
#  'c_2105',
#  'c_7986',
#  'c_7772',
#  'c_3146',
#  'c_688',
#  'c_5211',
#  'c_7965',
#  'c_6630',
#  'c_173',
#  'c_166',
#  'c_1680',
#  'c_8246',
#  'c_6608',
#  'c_5243',
#  'c_2386',
#  'c_734',
#  'c_5671',
#  'c_3455',
#  'c_4249',
#  'c_6396',
#  'c_3341',
#  'c_8446',
#  'c_7712',
#  'c_4891',
#  'c_5174',
#  'c_2650',
#  'c_7022',
#  'c_7072',
#  'c_1185',
#  'c_109',
#  'c_8388',
#  'c_3065',
#  'c_6065',
#  'c_3074',
#  'c_3501',
#  'c_7379',
#  'c_1987',
#  'c_588',
#  'c_8127',
#  'c_5925',
#  'c_4665',
#  'c_267',
#  'c_1307',
#  'c_515',
#  'c_5285',
#  'c_2485',
#  'c_3999',
#  'c_7431',
#  'c_4100',
#  'c_4631',
#  'c_3671',
#  'c_1151',
#  'c_1994',
#  'c_6903',
#  'c_3770',
#  'c_8383',
#  'c_2213',
#  'c_5484',
#  'c_7102',
#  'c_1911',
#  'c_833',
#  'c_2624',
#  'c_5955',
#  'c_7253',
#  'c_1536',
#  'c_2139',
#  'c_3105',
#  'c_3155',
#  'c_4944',
#  'c_6509',
#  'c_5978',
#  'c_4832',
#  'c_6373',
#  'c_5063',
#  'c_2506',
#  'c_1370',
#  'c_2121',
#  'c_3665',
#  'c_7818',
#  'c_258',
#  'c_1547',
#  'c_2903',
#  'c_394',
#  'c_4583',
#  'c_7879',
#  'c_7268',
#  'c_3950',
#  'c_2362',
#  'c_4982',
#  'c_8141',
#  'c_3685',
#  'c_2755',
#  'c_4366',
#  'c_113',
#  'c_1905',
#  'c_5379',
#  'c_1425',
#  'c_6200',
#  'c_5405',
#  'c_2088',
#  'c_7832',
#  'c_4759',
#  'c_6216',
#  'c_4756',
#  'c_5866',
#  'c_3984',
#  'c_742',
#  'c_1782',
#  'c_899',
#  'c_3555',
#  'c_5043',
#  'c_5616',
#  'c_1933',
#  'c_2343',
#  'c_2273',
#  'c_1093',
#  'c_2531',
#  'c_3887',
#  'c_7024',
#  'c_5519',
#  'c_2646',
#  'c_5167',
#  'c_2017',
#  'c_3975',
#  'c_7910',
#  'c_6368',
#  'c_3050',
#  'c_4376',
#  'c_3944',
#  'c_1830',
#  'c_6257',
#  'c_8265',
#  'c_7958',
#  'c_310',
#  'c_5322',
#  'c_3888',
#  'c_2890',
#  'c_5548',
#  'c_4560',
#  'c_931',
#  'c_320',
#  'c_4535',
#  'c_4983',
#  'c_7959',
#  'c_4858',
#  'c_1652',
#  'c_5790',
#  'c_1026',
#  'c_4991',
#  'c_3784',
#  'c_680',
#  'c_1447',
#  'c_2360',
#  'c_6544',
#  'c_5977',
#  'c_5840',
#  'c_5737',
#  'c_4596',
#  'c_3360',
#  'c_2488',
#  'c_6237',
#  'c_613',
#  'c_510',
#  'c_6340',
#  'c_1706',
#  'c_6150',
#  'c_58',
#  'c_8255',
#  'c_3935',
#  'c_389',
#  'c_6907',
#  'c_5355',
#  'c_4760',
#  'c_6718',
#  'c_5490',
#  'c_164',
#  'c_3462',
#  'c_1513',
#  'c_5974',
#  'c_6812',
#  'c_6349',
#  'c_6314',
#  'c_1316',
#  'c_8037',
#  'c_6376',
#  'c_7991',
#  'c_212',
#  'c_6852',
#  'c_3316',
#  'c_5037',
#  'c_4416',
#  'c_7635',
#  'c_8450',
#  'c_5302',
#  'c_2014',
#  'c_7344',
#  'c_4381',
#  'c_6554',
#  'c_1022',
#  'c_605',
#  'c_1908',
#  'c_4308',
#  'c_1901',
#  'c_891',
#  'c_6146',
#  'c_6939',
#  'c_1314',
#  'c_4921',
#  'c_1686',
#  'c_3115',
#  'c_5620',
#  'c_2461',
#  'c_5007',
#  'c_8221',
#  'c_4184',
#  'c_2508',
#  'c_5852',
#  'c_3587',
#  'c_3137',
#  'c_5287',
#  'c_2627',
#  'c_8124',
#  'c_5008',
#  'c_6913',
#  'c_4081',
#  'c_8549',
#  'c_4702',
#  'c_7342',
#  'c_746',
#  'c_1188',
#  'c_7153',
#  'c_333',
#  'c_6651',
#  'c_7829',
#  'c_5659',
#  'c_8421',
#  'c_604',
#  'c_7261',
#  'c_4856',
#  'c_7887',
#  'c_2103',
#  'c_8065',
#  'c_3318',
#  'c_3853',
#  'c_1912',
#  'c_1351',
#  'c_1663',
#  'c_3284',
#  'c_2913',
#  'c_5823',
#  'c_6324',
#  'c_3947',
#  'c_3546',
#  'c_881',
#  'c_345',
#  'c_1725',
#  'c_4545',
#  'c_1449',
#  'c_8565',
#  'c_4817',
#  'c_1113',
#  'c_4309',
#  'c_5116',
#  'c_4440',
#  'c_4586',
#  'c_1851',
#  'c_3902',
#  'c_7992',
#  'c_5642',
#  'c_6133',
#  'c_5766',
#  'c_3973',
#  'c_6683',
#  'c_2733',
#  'c_2826',
#  'c_7028',
#  'c_4508',
#  'c_6979',
#  'c_7388',
#  'c_2416',
#  'c_5999',
#  'c_6360',
#  'c_3276',
#  'c_5289',
#  'c_5078',
#  'c_6995',
#  'c_3714',
#  'c_1472',
#  'c_4391',
#  'c_7923',
#  'c_4793',
#  'c_6685',
#  'c_531',
#  'c_2130',
#  'c_4097',
#  'c_6595',
#  'c_8178',
#  'c_7360',
#  'c_850',
#  'c_7314',
#  'c_3906',
#  'c_4425',
#  'c_2987',
#  'c_2305',
#  'c_4633',
#  'c_2118',
#  'c_5878',
#  'c_2217',
#  'c_930',
#  'c_1016',
#  'c_1077',
#  'c_1030',
#  'c_7886',
#  'c_8493',
#  'c_3030',
#  'c_4844',
#  'c_4161',
#  'c_3179',
#  'c_1595',
#  'c_8498',
#  'c_3898',
#  'c_307',
#  'c_903',
#  'c_2020',
#  'c_1467',
#  'c_7525',
#  'c_1977',
#  'c_2278',
#  'c_6582',
#  'c_5740',
#  'c_603',
#  'c_8424',
#  'c_5715',
#  'c_7881',
#  'c_3914',
#  'c_2178',
#  'c_4582',
#  'c_4589',
#  'c_4663',
#  'c_6842',
#  'c_8486',
#  'c_6535',
#  'c_675',
#  'c_1835',
#  'c_3071',
#  'c_1511',
#  'c_4259',
#  'c_5231',
#  'c_4282',
#  'c_6142',
#  'c_2957',
#  'c_5143',
#  'c_706',
#  'c_6601',
#  'c_4876',
#  'c_4651',
#  'c_1886',
#  'c_7812',
#  'c_691',
#  'c_8371',
#  'c_268',
#  'c_825',
#  'c_185',
#  'c_3548',
#  'c_5337',
#  'c_1581',
#  'c_6619',
#  'c_4306',
#  'c_89',
#  'c_7201',
#  'c_4850',
#  'c_8289',
#  'c_2523',
#  'c_2184',
#  'c_5930',
#  'c_2796',
#  'c_4262',
#  'c_5833',
#  'c_4927',
#  'c_7783',
#  'c_8372',
#  'c_2559',
#  'c_3158',
#  'c_3250',
#  'c_1036',
#  'c_1926',
#  'c_3504',
#  'c_2140',
#  'c_2812',
#  'c_5390',
#  'c_4875',
#  'c_660',
#  'c_2214',
#  'c_4341',
#  'c_4870',
#  'c_700',
#  'c_3760',
#  'c_1723',
#  'c_2548',
#  'c_1671',
#  'c_4600',
#  'c_536',
#  'c_3700',
#  'c_4468',
#  'c_1124',
#  'c_8280',
#  'c_2839',
#  'c_7168',
#  'c_2904',
#  'c_2900',
#  'c_7004',
#  'c_2413',
#  'c_1503',
#  'c_7172',
#  'c_4918',
#  'c_3661',
#  'c_8377',
#  'c_1801',
#  'c_4352',
#  'c_671',
#  'c_8602',
#  'c_5028',
#  'c_5794',
#  'c_2634',
#  'c_7468',
#  'c_583',
#  'c_3493',
#  'c_3132',
#  'c_3597',
#  'c_7354',
#  'c_7343',
#  'c_3011',
#  'c_6090',
#  'c_2003',
#  'c_2433',
#  'c_6151',
#  'c_6390',
#  'c_3072',
#  'c_1379',
#  'c_4069',
#  'c_7650',
#  'c_992',
#  'c_2166',
#  'c_5538',
#  'c_1973',
#  'c_4905',
#  'c_5983',
#  'c_8100',
#  'c_7788',
#  'c_8106',
#  'c_3277',
#  'c_3401',
#  'c_5284',
#  'c_7792',
#  'c_1817',
#  'c_6332',
#  'c_2297',
#  'c_754',
#  'c_3034',
#  'c_5027',
#  'c_1952',
#  'c_7132',
#  'c_6880',
#  'c_743',
#  'c_55',
#  'c_8082',
#  'c_4824',
#  'c_1014',
#  'c_6632',
#  'c_5204',
#  'c_6118',
#  'c_4613',
#  'c_6542',
#  'c_444',
#  'c_1400',
#  'c_4802',
#  'c_2144',
#  'c_7178',
#  'c_242',
#  'c_7526',
#  'c_6199',
#  'c_4461',
#  'c_4091',
#  'c_1005',
#  'c_2183',
#  'c_6791',
#  'c_1880',
#  'c_408',
#  'c_1975',
#  'c_6261',
#  'c_707',
#  'c_5385',
#  'c_1213',
#  'c_8603',
#  'c_7120',
#  'c_5234',
#  'c_1838',
#  'c_1205',
#  'c_3621',
#  'c_2642',
#  'c_4194',
#  'c_3579',
#  'c_640',
#  'c_6134',
#  'c_8086',
#  'c_6248',
#  'c_2317',
#  'c_5085',
#  'c_8282',
#  'c_4288',
#  'c_8608',
#  'c_8396',
#  'c_8423',
#  'c_6217',
#  'c_2522',
#  'c_7509',
#  'c_423',
#  'c_1628',
#  'c_3297',
#  'c_1198',
#  'c_5151',
#  'c_2645',
#  'c_6971',
#  'c_8146',
#  'c_8183',
#  'c_7711',
#  'c_4812',
#  'c_5945',
#  'c_4400',
#  'c_7144',
#  'c_4244',
#  'c_141',
#  'c_4568',
#  'c_518',
#  'c_5315',
#  'c_7817',
#  'c_8191',
#  'c_8045',
#  'c_6077',
#  'c_417',
#  'c_1747',
#  'c_1068',
#  'c_2574',
#  'c_2350',
#  'c_5660',
#  'c_2803',
#  'c_3618',
#  'c_8201',
#  'c_5275',
#  'c_5921',
#  'c_3271',
#  'c_7790',
#  'c_4929',
#  'c_639',
#  'c_5207',
#  'c_3791',
#  'c_2794',
#  'c_2653',
#  'c_188',
#  'c_1818',
#  'c_7627',
#  'c_4521',
#  'c_3634',
#  'c_5309',
#  'c_1162',
#  'c_600',
#  'c_5661',
#  'c_5369',
#  'c_7045',
#  'c_5056',
#  'c_3197',
#  'c_3876',
#  'c_7524',
#  'c_6928',
#  'c_2482',
#  'c_7874',
#  'c_8253',
#  'c_692',
#  'c_1834',
#  'c_2390',
#  'c_8573',
#  'c_3259',
#  'c_4197',
#  'c_3664',
#  'c_6011',
#  'c_5475',
#  'c_1443',
#  'c_3496',
#  'c_4671',
#  'c_4037',
#  'c_5094',
#  'c_2459',
#  'c_1980',
#  'c_72',
#  'c_6322',
#  'c_8195',
#  'c_3705',
#  'c_3946',
#  'c_6571',
#  'c_2223',
#  'c_3718',
#  'c_3352',
#  'c_3192',
#  'c_3541',
#  'c_8558',
#  'c_3016',
#  'c_3180',
#  'c_5916',
#  'c_4378',
#  'c_6269',
#  'c_7272',
#  'c_388',
#  'c_8329',
#  'c_8110',
#  'c_1740',
#  'c_3432',
#  'c_2620',
#  'c_7906',
#  'c_677',
#  'c_6328',
#  'c_4986',
#  'c_5511',
#  'c_5601',
#  'c_5672',
#  'c_8250',
#  'c_7664',
#  'c_2128',
#  'c_6960',
#  'c_2926',
#  'c_5499',
#  'c_476',
#  'c_5118',
#  'c_4187',
#  'c_7304',
#  'c_3688',
#  'c_2245',
#  'c_7050',
#  'c_6531',
#  'c_4890',
#  'c_5250',
#  'c_1399',
#  'c_213',
#  'c_6964',
#  'c_3324',
#  'c_2176',
#  'c_6919',
#  'c_3256',
#  'c_7115',
#  'c_4296',
#  'c_4396',
#  'c_6425',
#  'c_8073',
#  'c_5392',
#  'c_2235',
#  'c_5559',
#  'c_6875',
#  'c_6660',
#  'c_8054',
#  'c_8123',
#  'c_3522',
#  'c_73',
#  'c_7623',
#  'c_2663',
#  'c_6089',
#  'c_3185',
#  'c_3720',
#  'c_184',
#  'c_3562',
#  'c_1373',
#  'c_7587',
#  'c_2621',
#  'c_6854',
#  'c_4021',
#  'c_2162',
#  'c_2408',
#  'c_1573',
#  'c_7324',
#  'c_6728',
#  'c_8277',
#  'c_14',
#  'c_5552',
#  'c_4732',
#  'c_4739',
#  'c_7633',
#  'c_5353',
#  'c_3736',
#  'c_7033',
#  'c_2982',
#  'c_8382',
#  'c_8206',
#  'c_471',
#  'c_3563',
#  'c_2196',
#  'c_3983',
#  'c_4641',
#  'c_486',
#  'c_5993',
#  'c_1147',
#  'c_7240',
#  'c_7666',
#  'c_6985',
#  'c_1572',
#  'c_2100',
#  'c_1586',
#  'c_4055',
#  'c_7970',
#  'c_1731',
#  'c_1170',
#  'c_1841',
#  'c_1942',
#  'c_5296',
#  'c_6874',
#  'c_3590',
#  'c_3323',
#  'c_4745',
#  'c_7208',
#  'c_5238',
#  'c_8526',
#  'c_1473',
#  'c_1565',
#  'c_5458',
#  'c_2232',
#  'c_7656',
#  'c_968',
#  'c_7371',
#  'c_7181',
#  'c_4302',
#  'c_3215',
#  'c_3238',
#  'c_6467',
#  'c_7521',
#  'c_4713',
#  'c_7474',
#  'c_6948',
#  'c_1626',
#  'c_7780',
#  'c_7213',
#  'c_6633',
#  'c_1256',
#  'c_7868',
#  'c_6961',
#  'c_3560',
#  'c_5042',
#  'c_5199',
#  'c_1960',
#  'c_159',
#  'c_7287',
#  'c_4162',
#  'c_6457',
#  'c_5149',
#  'c_3707',
#  'c_7',
#  'c_1803',
#  'c_2718',
#  'c_2554',
#  'c_7290',
#  'c_5590',
#  'c_4825',
#  'c_3294',
#  'c_508',
#  'c_527',
#  'c_4419',
#  'c_6526',
#  'c_1864',
#  'c_7628',
#  'c_3551',
#  'c_481',
#  'c_1018',
#  'c_4840',
#  'c_2905',
#  'c_120',
#  'c_617',
#  'c_6963',
#  'c_7171',
#  'c_1853',
#  ...]

# %%
customers.describe(include='all')
# Out:
#        client_id   sex        birth
# count       8623  8623  8623.000000
# unique      8623     2          NaN
# top       c_4410     f          NaN
# freq           1  4491          NaN
# mean         NaN   NaN  1978.280877
# std          NaN   NaN    16.919535
# min          NaN   NaN  1929.000000
# 25%          NaN   NaN  1966.000000
# 50%          NaN   NaN  1979.000000
# 75%          NaN   NaN  1992.000000
# max          NaN   NaN  2004.000000

# %% [markdown]
# On voit qu'on a plus de femme que d'hommes, les plus jeunes sont nés en 2004, les plus âgés en 1929, moyenne d'âge 1978 soit 43 ans....

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 10px; color: RGB(51,165,182); ">2.2- products </h3>

# %%
products.head()
# Out:
#   id_prod  price  categ
# 0  0_1421  19.99      0
# 1  0_1368   5.13      0
# 2   0_731  17.99      0
# 3   1_587   4.99      1
# 4  0_1507   3.99      0

# %%
print(products.shape)
print(products.dtypes)
# Out:
# (3287, 3)
# id_prod     object
# price      float64
# categ        int64
# dtype: object

# %%
#Vérif PK --> id_prod
print(products['id_prod'].nunique())
print(products['id_prod'].nunique() == products.shape[0])
# Out:
# 3287
# True

# %% [markdown]
# ## Nettoyage

# %%
print(products['id_prod'].duplicated().sum())
print(products.isna().sum())
# Out:
# 0
# id_prod    0
# price      0
# categ      0
# dtype: int64

# %%
print(products["price"].min())
print(products["price"].max())
# Out:
# -1.0
# 300.0

# %%
# On peut pas avoir des prix en nég et ça ne semble pas être un vrai pdt car T_0
products[products["price"] == -1]
# Out:
#     id_prod  price  categ
# 731     T_0   -1.0      0

# %%
# Suppression :
products.drop(731, axis=0, inplace=True)

# %%
# La on touche pas, on verra plus tard
products.loc[products["price"] == 300]
# Out:
#     id_prod  price  categ
# 947     2_2  300.0      2

# %%
# On a 3 catégories différentes et les pdts commencent par 0 1 ou 2 selon la catégorie à laquelle ils sont associés
products["categ"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
# Visu du nb de produits par categ
products['categ'].value_counts().sort_values(ascending=False)
# Out:
# 0    2308
# 1     739
# 2     239
# Name: categ, dtype: int64

# %%
categ0 = products.loc[products['categ'] == 0]
categ0
# Out:
#      id_prod  price  categ
# 0     0_1421  19.99      0
# 1     0_1368   5.13      0
# 2      0_731  17.99      0
# 4     0_1507   3.99      0
# 5     0_1163   9.99      0
# ...      ...    ...    ...
# 3280  0_1314  20.63      0
# 3281   0_607  14.99      0
# 3283   0_146  17.14      0
# 3284   0_802  11.22      0
# 3286  0_1920  25.16      0
#
# [2308 rows x 3 columns]

# %%
# Les prix vont de 62c a 41E
categ0["price"].sort_values()
# Out:
# 2355     0.62
# 2272     0.62
# 370      0.66
# 1211     0.77
# 1530     0.80
#         ...
# 569     37.99
# 2663    37.99
# 1360    39.58
# 2809    39.99
# 47      40.99
# Name: price, Length: 2308, dtype: float64

# %%
categ1 = products.loc[products['categ'] == 1]
categ1
# Out:
#      id_prod  price  categ
# 3      1_587   4.99      1
# 6      1_463  36.99      1
# 11     1_178  51.92      1
# 12     1_143   9.99      1
# 13     1_314   9.00      1
# ...      ...    ...    ...
# 3270   1_651  18.99      1
# 3272   1_272   4.55      1
# 3278   1_387   9.99      1
# 3279   1_331  55.99      1
# 3285   1_140  38.56      1
#
# [739 rows x 3 columns]

# %%
# Les prix vont de 2E a 81E
categ1["price"].sort_values()
# Out:
# 3243     2.00
# 2853     2.24
# 2496     2.64
# 2366     2.95
# 1278     2.99
#         ...
# 2962    72.75
# 2827    73.99
# 808     78.83
# 879     79.99
# 824     80.99
# Name: price, Length: 739, dtype: float64

# %%
categ2 = products.loc[products['categ'] == 2]
categ2
# Out:
#      id_prod   price  categ
# 10     2_228  225.17      2
# 38     2_100   72.11      2
# 64      2_89  107.99      2
# 73     2_225  157.99      2
# 79     2_187  157.99      2
# ...      ...     ...    ...
# 3188    2_99   84.99      2
# 3196   2_238   93.92      2
# 3267   2_101   63.99      2
# 3271   2_123  147.99      2
# 3282    2_23  115.99      2
#
# [239 rows x 3 columns]

# %%
# Les prix vont de 31E a 300E
categ2["price"].sort_values()
# Out:
# 3099     30.99
# 390      32.99
# 3095     32.99
# 770      33.99
# 1717     34.23
#          ...
# 2779    233.54
# 1436    236.99
# 394     247.22
# 724     254.44
# 947     300.00
# Name: price, Length: 239, dtype: float64

# %% [markdown]
# On ne peut pas réellement dire que le prix est un indicateur de catégorie car tous se chevauchent. En revanche, le plus petit 62c par la cat0 et 300E pour la dernière categ.

# %%
products.describe(include="all")
# Out:
#        id_prod        price        categ
# count     3286  3286.000000  3286.000000
# unique    3286          NaN          NaN
# top     0_1421          NaN          NaN
# freq         1          NaN          NaN
# mean       NaN    21.863597     0.370359
# std        NaN    29.849786     0.615446
# min        NaN     0.620000     0.000000
# 25%        NaN     6.990000     0.000000
# 50%        NaN    13.075000     0.000000
# 75%        NaN    22.990000     1.000000
# max        NaN   300.000000     2.000000

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 10px; color: RGB(51,165,182); ">2.3- Transactions </h3>

# %%
transactions.head()
# Out:
#   id_prod                        date session_id client_id
# 0  0_1518  2022-05-20 13:21:29.043970   s_211425     c_103
# 1   1_251  2022-02-02 07:55:19.149409   s_158752    c_8534
# 2  0_1277  2022-06-18 15:44:33.155329   s_225667    c_6714
# 3   2_209  2021-06-24 04:19:29.835891    s_52962    c_6941
# 4  0_1509  2023-01-11 08:22:08.194479   s_325227    c_4232

# %%
print(transactions.shape)
print(transactions.dtypes)
# Out:
# (679532, 4)
# id_prod       object
# date          object
# session_id    object
# client_id     object
# dtype: object

# %%
# Je me suis aperçue de ces lignes de test :
transactions.loc[transactions["date"].str.startswith('test_')]
# Out:
#        id_prod                             date session_id client_id
# 3019       T_0  test_2021-03-01 02:30:02.237419        s_0      ct_0
# 5138       T_0  test_2021-03-01 02:30:02.237425        s_0      ct_0
# 9668       T_0  test_2021-03-01 02:30:02.237437        s_0      ct_1
# 10728      T_0  test_2021-03-01 02:30:02.237436        s_0      ct_0
# 15292      T_0  test_2021-03-01 02:30:02.237430        s_0      ct_0
# ...        ...                              ...        ...       ...
# 657830     T_0  test_2021-03-01 02:30:02.237417        s_0      ct_0
# 662081     T_0  test_2021-03-01 02:30:02.237427        s_0      ct_1
# 670680     T_0  test_2021-03-01 02:30:02.237449        s_0      ct_1
# 671647     T_0  test_2021-03-01 02:30:02.237424        s_0      ct_1
# 679180     T_0  test_2021-03-01 02:30:02.237425        s_0      ct_1
#
# [200 rows x 4 columns]

# %%
# On va pouvoir les supp car ce sont des tests :
transactions.drop(transactions[transactions['id_prod'] == "T_0"].index, inplace=True)

# %%
# Vérif unicité pk : Vu que notre format date est en nanoseconde on va voir si on peut l'utiliser en tant que pk
print(transactions[["id_prod", 'date', 'client_id', "session_id" ]].nunique())
print(transactions["date"].nunique() == transactions.shape[0])
# Out:
# id_prod         3266
# date          679332
# client_id       8600
# session_id    342315
# dtype: int64
# True

# %%
# On a 678505 lignes contre 679332 pour date
transactions.groupby(["id_prod", 'client_id', "session_id"]).count()
# Out:
#                               date
# id_prod client_id session_id
# 0_0     c_1004    s_908          1
#         c_1011    s_167174       1
#                   s_180968       1
#                   s_195932       1
#                   s_343439       1
# ...                            ...
# 2_99    c_5828    s_241374       1
#                   s_329932       1
#         c_7135    s_296127       1
#                   s_310606       1
#                   s_61009        1
#
# [678505 rows x 1 columns]

# %%
# Ca veut dire que pour une date unique, on a 1,2 ou 3 x la mm occurence client, session et pdts (a la mm session, le client a acheté 3x le mm pdt,donc date est bien notre pk)
transactions.groupby(["id_prod", 'client_id', "session_id"]).count()['date'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %% [markdown]
# rien qu'avec la ligne avec unique(), vu qu'il n'y a pas que des 1, ca veut dire qu'il y a des doublons voir des triplets sur ce groupement de clés.Pour la date, on a autant de dates uniques que de lignes donc c'est bien la pk.

# %%
# Juste pour regarder : On crée un mask où on veut retourner ttes les lignes qui sont égales à 2
mask = transactions.groupby(["id_prod", 'client_id', "session_id"]).count()['date'] == 2   
# On va afficher ts les "true"
transactions.groupby(["id_prod", 'client_id', "session_id"]).count().loc[mask]
# Out:
#                               date
# id_prod client_id session_id
# 0_0     c_2180    s_20639        2
#         c_2867    s_7906         2
#         c_7680    s_298009       2
#                   s_6760         2
# 0_1023  c_857     s_192744       2
# ...                            ...
# 2_46    c_8597    s_44304        2
# 2_79    c_1865    s_123824       2
#                   s_198190       2
#         c_822     s_256697       2
#                   s_65485        2
#
# [823 rows x 1 columns]

# %%
print(transactions['date'].duplicated().sum())
print(transactions.isna().sum())
# Out:
# 0
# id_prod       0
# date          0
# session_id    0
# client_id     0
# dtype: int64

# %%
print(transactions['date'].max())
print(transactions['date'].min())
# Out:
# 2023-02-28 23:58:30.792755
# 2021-03-01 00:01:07.843138

# %% [markdown]
# On constate que notre jeu de données est futuriste.
# - Nous pouvons dire pour garder toutes les données que nous sommes en mars 2023

# %%
transactions['id_prod'].value_counts().sort_values(ascending=False).head(5)
# Out:
# 1_369    2252
# 1_417    2189
# 1_414    2180
# 1_498    2128
# 1_425    2096
# Name: id_prod, dtype: int64

# %%
transactions['session_id'].value_counts().sort_values(ascending=False).head(5)
# Out:
# s_118668    14
# s_179575    13
# s_342045    13
# s_96857     13
# s_215292    13
# Name: session_id, dtype: int64

# %%
transactions['client_id'].value_counts().sort_values(ascending=False).head(5)
# Out:
# c_1609    25488
# c_6714     9187
# c_3454     6773
# c_4958     5195
# c_3263      403
# Name: client_id, dtype: int64

# %%
# Modification de date object en datetime
transactions['date'] = pd.to_datetime(transactions['date'])

# %%
transactions.describe()
# Out:
# C:\Users\Camil\AppData\Local\Temp/ipykernel_12256/3177449877.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   transactions.describe()
#        id_prod                        date session_id client_id
# count   679332                      679332     679332    679332
# unique    3266                      679332     342315      8600
# top      1_369  2022-05-20 13:21:29.043970   s_118668    c_1609
# freq      2252                           1         14     25488
# first      NaN  2021-03-01 00:01:07.843138        NaN       NaN
# last       NaN  2023-02-28 23:58:30.792755        NaN       NaN

# %% [markdown]
# On sait qu'on a : 3266 id_prod uniques, 679 332 transactions uniques, 8600 client_id uniques, 342 315 session_id uniques. Le produit le plus acheté est le 1_369 (x2252), le client le plus régulier c_1609 (25 488 transactions), la session la plus active s_118668 (x14)
#
# chaque prod_id commençant par la lettre 0,1 ou 2 correspond à la catégorie du produit.
#
# Chaque session_id correspond à un achat et il peut y avoir plusieurs achats pour la même session
#
# Nous sommes en mars 2023

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 10px; color: RGB(51,165,182); ">2.4- Jointures </h3>

# %% [markdown]
# # Merge entre customers & transactions

# %%
# Merge sur la clé "client_id" : 
clients = pd.merge(left= transactions, 
               right= customers, how="outer", on="client_id", indicator=True)
clients.head()
# Out:
#   id_prod                       date session_id client_id sex  birth _merge
# 0  0_1518 2022-05-20 13:21:29.043970   s_211425     c_103   f   1986   both
# 1  0_1627 2022-06-18 05:55:31.816994   s_225494     c_103   f   1986   both
# 2  0_1104 2023-02-08 17:31:06.898425   s_338755     c_103   f   1986   both
# 3  0_1390 2021-04-20 06:18:39.939761    s_23078     c_103   f   1986   both
# 4  0_1547 2022-03-15 19:54:53.904123   s_179629     c_103   f   1986   both

# %%
print(clients.shape)
print(clients.dtypes)
# Out:
# (679355, 7)
# id_prod               object
# date          datetime64[ns]
# session_id            object
# client_id             object
# sex                   object
# birth                  int64
# _merge              category
# dtype: object

# %%
# vérif != de both: On a 23 clients identifiés qui n'auraient pas acheté de livre
clients_sans_achat = clients[clients["_merge"]!= "both"]
print(len(clients_sans_achat))
clients_sans_achat
# Out:
# 23
#        id_prod date session_id client_id sex  birth      _merge
# 679332     NaN  NaT        NaN    c_8253   f   2001  right_only
# 679333     NaN  NaT        NaN    c_3789   f   1997  right_only
# 679334     NaN  NaT        NaN    c_4406   f   1998  right_only
# 679335     NaN  NaT        NaN      ct_0   f   2001  right_only
# 679336     NaN  NaT        NaN    c_2706   f   1967  right_only
# 679337     NaN  NaT        NaN    c_3443   m   1959  right_only
# 679338     NaN  NaT        NaN    c_4447   m   1956  right_only
# 679339     NaN  NaT        NaN    c_3017   f   1992  right_only
# 679340     NaN  NaT        NaN    c_4086   f   1992  right_only
# 679341     NaN  NaT        NaN    c_6930   m   2004  right_only
# 679342     NaN  NaT        NaN    c_4358   m   1999  right_only
# 679343     NaN  NaT        NaN    c_8381   f   1965  right_only
# 679344     NaN  NaT        NaN    c_1223   m   1963  right_only
# 679345     NaN  NaT        NaN    c_6862   f   2002  right_only
# 679346     NaN  NaT        NaN    c_5245   f   2004  right_only
# 679347     NaN  NaT        NaN    c_5223   m   2003  right_only
# 679348     NaN  NaT        NaN    c_6735   m   2004  right_only
# 679349     NaN  NaT        NaN     c_862   f   1956  right_only
# 679350     NaN  NaT        NaN    c_7584   f   1960  right_only
# 679351     NaN  NaT        NaN      c_90   m   2001  right_only
# 679352     NaN  NaT        NaN     c_587   m   1993  right_only
# 679353     NaN  NaT        NaN      ct_1   m   2001  right_only
# 679354     NaN  NaT        NaN    c_3526   m   1956  right_only

# %%
clients = clients[clients["_merge"] == "both"]
clients
# Out:
#        id_prod                       date session_id client_id sex  birth  \
# 0       0_1518 2022-05-20 13:21:29.043970   s_211425     c_103   f   1986
# 1       0_1627 2022-06-18 05:55:31.816994   s_225494     c_103   f   1986
# 2       0_1104 2023-02-08 17:31:06.898425   s_338755     c_103   f   1986
# 3       0_1390 2021-04-20 06:18:39.939761    s_23078     c_103   f   1986
# 4       0_1547 2022-03-15 19:54:53.904123   s_179629     c_103   f   1986
# ...        ...                        ...        ...       ...  ..    ...
# 679327  0_1509 2021-05-15 08:17:35.835342    s_34762    c_8114   m   1962
# 679328   1_152 2021-11-08 17:12:27.637349   s_116675     c_240   m   1998
# 679329   2_207 2021-06-01 04:31:16.088314    s_42418     c_305   f   1996
# 679330   1_521 2022-10-18 00:38:49.629165   s_284060     c_305   f   1996
# 679331   1_521 2021-12-18 00:38:49.629165   s_135996     c_305   f   1996
#
#        _merge
# 0        both
# 1        both
# 2        both
# 3        both
# 4        both
# ...       ...
# 679327   both
# 679328   both
# 679329   both
# 679330   both
# 679331   both
#
# [679332 rows x 7 columns]

# %%
clients.drop(["_merge"], axis=1, inplace=True)

# %%
print(clients.duplicated().sum())
print(clients.isna().sum())
print(clients.shape)
# Out:
# 0
# id_prod       0
# date          0
# session_id    0
# client_id     0
# sex           0
# birth         0
# dtype: int64
# (679332, 6)

# %% [markdown]
# # Merge entre clients & products

# %%
# Merge sur la clé "id_prod" : 
rapport = pd.merge(left= clients, 
               right= products, how="outer", on="id_prod", indicator=True)
rapport.head()
# Out:
#   id_prod                       date session_id client_id sex   birth  price  \
# 0  0_1518 2022-05-20 13:21:29.043970   s_211425     c_103   f  1986.0   4.18
# 1  0_1518 2021-07-20 13:21:29.043970    s_64849     c_103   f  1986.0   4.18
# 2  0_1518 2022-08-20 13:21:29.043970   s_255965     c_103   f  1986.0   4.18
# 3  0_1518 2021-05-09 11:52:55.100386    s_32104    c_6714   f  1968.0   4.18
# 4  0_1518 2022-05-30 01:17:07.487046   s_216118    c_6714   f  1968.0   4.18
#
#    categ _merge
# 0    0.0   both
# 1    0.0   both
# 2    0.0   both
# 3    0.0   both
# 4    0.0   both

# %%
print(rapport.shape)
print(rapport.dtypes)
# Out:
# (679353, 9)
# id_prod               object
# date          datetime64[ns]
# session_id            object
# client_id             object
# sex                   object
# birth                float64
# price                float64
# categ                float64
# _merge              category
# dtype: object

# %%
# Vérif right : Ici on aurait 21 pdts référencés mais pas vendus
pdts_pas_vendus = rapport[rapport["_merge"] == "right_only"]
print(len(pdts_pas_vendus))
print(pdts_pas_vendus['id_prod'].nunique())
pdts_pas_vendus
# Out:
# 21
# 21
#        id_prod date session_id client_id  sex  birth   price  categ  \
# 679332  0_1016  NaT        NaN       NaN  NaN    NaN   35.06    0.0
# 679333  0_1780  NaT        NaN       NaN  NaN    NaN    1.67    0.0
# 679334  0_1062  NaT        NaN       NaN  NaN    NaN   20.08    0.0
# 679335  0_1119  NaT        NaN       NaN  NaN    NaN    2.99    0.0
# 679336  0_1014  NaT        NaN       NaN  NaN    NaN    1.15    0.0
# 679337     1_0  NaT        NaN       NaN  NaN    NaN   31.82    1.0
# 679338  0_1318  NaT        NaN       NaN  NaN    NaN   20.92    0.0
# 679339  0_1800  NaT        NaN       NaN  NaN    NaN   22.05    0.0
# 679340  0_1645  NaT        NaN       NaN  NaN    NaN    2.99    0.0
# 679341   0_322  NaT        NaN       NaN  NaN    NaN    2.99    0.0
# 679342  0_1620  NaT        NaN       NaN  NaN    NaN    0.80    0.0
# 679343  0_1025  NaT        NaN       NaN  NaN    NaN   24.99    0.0
# 679344    2_87  NaT        NaN       NaN  NaN    NaN  220.99    2.0
# 679345   1_394  NaT        NaN       NaN  NaN    NaN   39.73    1.0
# 679346    2_72  NaT        NaN       NaN  NaN    NaN  141.32    2.0
# 679347   0_310  NaT        NaN       NaN  NaN    NaN    1.94    0.0
# 679348  0_1624  NaT        NaN       NaN  NaN    NaN   24.50    0.0
# 679349    2_86  NaT        NaN       NaN  NaN    NaN  132.36    2.0
# 679350   0_299  NaT        NaN       NaN  NaN    NaN   22.99    0.0
# 679351   0_510  NaT        NaN       NaN  NaN    NaN   23.66    0.0
# 679352  0_2308  NaT        NaN       NaN  NaN    NaN   20.28    0.0
#
#             _merge
# 679332  right_only
# 679333  right_only
# 679334  right_only
# 679335  right_only
# 679336  right_only
# 679337  right_only
# 679338  right_only
# 679339  right_only
# 679340  right_only
# 679341  right_only
# 679342  right_only
# 679343  right_only
# 679344  right_only
# 679345  right_only
# 679346  right_only
# 679347  right_only
# 679348  right_only
# 679349  right_only
# 679350  right_only
# 679351  right_only
# 679352  right_only

# %%
# Vérif left
rapport[rapport["_merge"] == "left_only"]
# Out:
#        id_prod                       date session_id client_id sex   birth  \
# 311747  0_2245 2021-04-22 04:57:20.090378    s_23987    c_6714   f  1968.0
# 311748  0_2245 2021-06-05 17:04:43.982913    s_44481    c_6714   f  1968.0
# 311749  0_2245 2022-04-05 17:04:43.982913   s_189669    c_6714   f  1968.0
# 311750  0_2245 2022-05-05 17:04:43.982913   s_204093    c_6714   f  1968.0
# 311751  0_2245 2022-12-05 17:04:43.982913   s_307520    c_6714   f  1968.0
# ...        ...                        ...        ...       ...  ..     ...
# 311963  0_2245 2021-10-19 09:32:03.667461   s_107022    c_6128   m  1986.0
# 311964  0_2245 2021-11-12 09:25:22.905886   s_118458    c_7416   m  1933.0
# 311965  0_2245 2021-08-22 08:51:27.564509    s_79102    c_6752   m  1987.0
# 311966  0_2245 2022-04-22 08:51:27.564509   s_197669    c_6752   m  1987.0
# 311967  0_2245 2021-05-20 07:44:21.415061    s_36985    c_1450   f  1959.0
#
#         price  categ     _merge
# 311747    NaN    NaN  left_only
# 311748    NaN    NaN  left_only
# 311749    NaN    NaN  left_only
# 311750    NaN    NaN  left_only
# 311751    NaN    NaN  left_only
# ...       ...    ...        ...
# 311963    NaN    NaN  left_only
# 311964    NaN    NaN  left_only
# 311965    NaN    NaN  left_only
# 311966    NaN    NaN  left_only
# 311967    NaN    NaN  left_only
#
# [221 rows x 9 columns]

# %%
# Vérif si ces 221 lignes correspondent au pdt 0_2245 ou plusieurs pdts :
left_only = rapport.loc[(rapport["_merge"] == "left_only") & (rapport["id_prod"] == '0_2245')]
left_only
# Out:
#        id_prod                       date session_id client_id sex   birth  \
# 311747  0_2245 2021-04-22 04:57:20.090378    s_23987    c_6714   f  1968.0
# 311748  0_2245 2021-06-05 17:04:43.982913    s_44481    c_6714   f  1968.0
# 311749  0_2245 2022-04-05 17:04:43.982913   s_189669    c_6714   f  1968.0
# 311750  0_2245 2022-05-05 17:04:43.982913   s_204093    c_6714   f  1968.0
# 311751  0_2245 2022-12-05 17:04:43.982913   s_307520    c_6714   f  1968.0
# ...        ...                        ...        ...       ...  ..     ...
# 311963  0_2245 2021-10-19 09:32:03.667461   s_107022    c_6128   m  1986.0
# 311964  0_2245 2021-11-12 09:25:22.905886   s_118458    c_7416   m  1933.0
# 311965  0_2245 2021-08-22 08:51:27.564509    s_79102    c_6752   m  1987.0
# 311966  0_2245 2022-04-22 08:51:27.564509   s_197669    c_6752   m  1987.0
# 311967  0_2245 2021-05-20 07:44:21.415061    s_36985    c_1450   f  1959.0
#
#         price  categ     _merge
# 311747    NaN    NaN  left_only
# 311748    NaN    NaN  left_only
# 311749    NaN    NaN  left_only
# 311750    NaN    NaN  left_only
# 311751    NaN    NaN  left_only
# ...       ...    ...        ...
# 311963    NaN    NaN  left_only
# 311964    NaN    NaN  left_only
# 311965    NaN    NaN  left_only
# 311966    NaN    NaN  left_only
# 311967    NaN    NaN  left_only
#
# [221 rows x 9 columns]

# %% [markdown]
# Effectivement il n'y a que pour ce produit qu'on a des nan sur price et categ on va peut etre pouvoir faire quelque chose :
#
# Il est manquant dans notre df products donc on ne peut pas savoir le prix, et ce sont les 221 lignes de transactions.
#
# - On sait que le premier chiff de l'id pdt est sa catégorie, on va remplacer les nan categ par 0
# - Pour le prix on peut faire une moyenne de la categ 0 et remplacer les nan par ce résultat

# %%
# remplacement par 0 pour la categ
left_only['categ'].fillna(0, inplace=True )
left_only
# Out:
# C:\Users\Camil\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#        id_prod                       date session_id client_id sex   birth  \
# 311747  0_2245 2021-04-22 04:57:20.090378    s_23987    c_6714   f  1968.0
# 311748  0_2245 2021-06-05 17:04:43.982913    s_44481    c_6714   f  1968.0
# 311749  0_2245 2022-04-05 17:04:43.982913   s_189669    c_6714   f  1968.0
# 311750  0_2245 2022-05-05 17:04:43.982913   s_204093    c_6714   f  1968.0
# 311751  0_2245 2022-12-05 17:04:43.982913   s_307520    c_6714   f  1968.0
# ...        ...                        ...        ...       ...  ..     ...
# 311963  0_2245 2021-10-19 09:32:03.667461   s_107022    c_6128   m  1986.0
# 311964  0_2245 2021-11-12 09:25:22.905886   s_118458    c_7416   m  1933.0
# 311965  0_2245 2021-08-22 08:51:27.564509    s_79102    c_6752   m  1987.0
# 311966  0_2245 2022-04-22 08:51:27.564509   s_197669    c_6752   m  1987.0
# 311967  0_2245 2021-05-20 07:44:21.415061    s_36985    c_1450   f  1959.0
#
#         price  categ     _merge
# 311747    NaN    0.0  left_only
# 311748    NaN    0.0  left_only
# 311749    NaN    0.0  left_only
# 311750    NaN    0.0  left_only
# 311751    NaN    0.0  left_only
# ...       ...    ...        ...
# 311963    NaN    0.0  left_only
# 311964    NaN    0.0  left_only
# 311965    NaN    0.0  left_only
# 311966    NaN    0.0  left_only
# 311967    NaN    0.0  left_only
#
# [221 rows x 9 columns]

# %%
# moyenne de la categ 0 : 
categ_0 = rapport.loc[rapport['categ']==0]
categ_0["price"].mean()
# Out:
# 10.63832969498281

# %%
#imputation par la moyenne
left_only['price'].fillna(10.64, inplace=True )
left_only
# Out:
# C:\Users\Camil\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#        id_prod                       date session_id client_id sex   birth  \
# 311747  0_2245 2021-04-22 04:57:20.090378    s_23987    c_6714   f  1968.0
# 311748  0_2245 2021-06-05 17:04:43.982913    s_44481    c_6714   f  1968.0
# 311749  0_2245 2022-04-05 17:04:43.982913   s_189669    c_6714   f  1968.0
# 311750  0_2245 2022-05-05 17:04:43.982913   s_204093    c_6714   f  1968.0
# 311751  0_2245 2022-12-05 17:04:43.982913   s_307520    c_6714   f  1968.0
# ...        ...                        ...        ...       ...  ..     ...
# 311963  0_2245 2021-10-19 09:32:03.667461   s_107022    c_6128   m  1986.0
# 311964  0_2245 2021-11-12 09:25:22.905886   s_118458    c_7416   m  1933.0
# 311965  0_2245 2021-08-22 08:51:27.564509    s_79102    c_6752   m  1987.0
# 311966  0_2245 2022-04-22 08:51:27.564509   s_197669    c_6752   m  1987.0
# 311967  0_2245 2021-05-20 07:44:21.415061    s_36985    c_1450   f  1959.0
#
#         price  categ     _merge
# 311747  10.64    0.0  left_only
# 311748  10.64    0.0  left_only
# 311749  10.64    0.0  left_only
# 311750  10.64    0.0  left_only
# 311751  10.64    0.0  left_only
# ...       ...    ...        ...
# 311963  10.64    0.0  left_only
# 311964  10.64    0.0  left_only
# 311965  10.64    0.0  left_only
# 311966  10.64    0.0  left_only
# 311967  10.64    0.0  left_only
#
# [221 rows x 9 columns]

# %%
# On va garder tout ce qui est "both" et rajouter nos lignes : 
rapport = rapport[rapport['_merge'] == 'both']
rapport = rapport.append(left_only)
rapport
# Out:
#        id_prod                       date session_id client_id sex   birth  \
# 0       0_1518 2022-05-20 13:21:29.043970   s_211425     c_103   f  1986.0
# 1       0_1518 2021-07-20 13:21:29.043970    s_64849     c_103   f  1986.0
# 2       0_1518 2022-08-20 13:21:29.043970   s_255965     c_103   f  1986.0
# 3       0_1518 2021-05-09 11:52:55.100386    s_32104    c_6714   f  1968.0
# 4       0_1518 2022-05-30 01:17:07.487046   s_216118    c_6714   f  1968.0
# ...        ...                        ...        ...       ...  ..     ...
# 311963  0_2245 2021-10-19 09:32:03.667461   s_107022    c_6128   m  1986.0
# 311964  0_2245 2021-11-12 09:25:22.905886   s_118458    c_7416   m  1933.0
# 311965  0_2245 2021-08-22 08:51:27.564509    s_79102    c_6752   m  1987.0
# 311966  0_2245 2022-04-22 08:51:27.564509   s_197669    c_6752   m  1987.0
# 311967  0_2245 2021-05-20 07:44:21.415061    s_36985    c_1450   f  1959.0
#
#         price  categ     _merge
# 0        4.18    0.0       both
# 1        4.18    0.0       both
# 2        4.18    0.0       both
# 3        4.18    0.0       both
# 4        4.18    0.0       both
# ...       ...    ...        ...
# 311963  10.64    0.0  left_only
# 311964  10.64    0.0  left_only
# 311965  10.64    0.0  left_only
# 311966  10.64    0.0  left_only
# 311967  10.64    0.0  left_only
#
# [679332 rows x 9 columns]

# %%
rapport.drop(["_merge"], axis=1, inplace=True)

# %%
print(rapport.duplicated().sum())
print(rapport.isna().sum())
# Out:
# 0
# id_prod       0
# date          0
# session_id    0
# client_id     0
# sex           0
# birth         0
# price         0
# categ         0
# dtype: int64

# %%
# Modifier birth et categ en int + remis date en datetime
rapport["birth"]=rapport["birth"].astype(int)
rapport["categ"]=rapport["categ"].astype(int)
rapport['date'] = pd.to_datetime(rapport['date'])
print(rapport.dtypes)
print(rapport.shape)
# Out:
# id_prod               object
# date          datetime64[ns]
# session_id            object
# client_id             object
# sex                   object
# birth                  int32
# price                float64
# categ                  int32
# dtype: object
# (679332, 8)

# %%
# Remise des index dans le bon ordre
rapport.reset_index(inplace=True, drop=True)
rapport
# Out:
#        id_prod                       date session_id client_id sex  birth  \
# 0       0_1518 2022-05-20 13:21:29.043970   s_211425     c_103   f   1986
# 1       0_1518 2021-07-20 13:21:29.043970    s_64849     c_103   f   1986
# 2       0_1518 2022-08-20 13:21:29.043970   s_255965     c_103   f   1986
# 3       0_1518 2021-05-09 11:52:55.100386    s_32104    c_6714   f   1968
# 4       0_1518 2022-05-30 01:17:07.487046   s_216118    c_6714   f   1968
# ...        ...                        ...        ...       ...  ..    ...
# 679327  0_2245 2021-10-19 09:32:03.667461   s_107022    c_6128   m   1986
# 679328  0_2245 2021-11-12 09:25:22.905886   s_118458    c_7416   m   1933
# 679329  0_2245 2021-08-22 08:51:27.564509    s_79102    c_6752   m   1987
# 679330  0_2245 2022-04-22 08:51:27.564509   s_197669    c_6752   m   1987
# 679331  0_2245 2021-05-20 07:44:21.415061    s_36985    c_1450   f   1959
#
#         price  categ
# 0        4.18      0
# 1        4.18      0
# 2        4.18      0
# 3        4.18      0
# 4        4.18      0
# ...       ...    ...
# 679327  10.64      0
# 679328  10.64      0
# 679329  10.64      0
# 679330  10.64      0
# 679331  10.64      0
#
# [679332 rows x 8 columns]

# %% [markdown]
# <div style="border: 1px solid RGB(51,165,182);" >
# <h3 style="margin: auto; padding: 10px; color: RGB(51,165,182); ">2.5- Amélioration df </h3>

# %%
#Création colonne temp de la transaction pour que ça soit plus clair et utile pour la suite
rapport['transac_year'] = pd.DatetimeIndex(rapport['date']).year
rapport['weekday'] = rapport['date'].dt.day_name() 
rapport['month'] = pd.DatetimeIndex(rapport['date']).month
rapport.dtypes
rapport
# Out:
#        id_prod                       date session_id client_id sex  birth  \
# 0       0_1518 2022-05-20 13:21:29.043970   s_211425     c_103   f   1986
# 1       0_1518 2021-07-20 13:21:29.043970    s_64849     c_103   f   1986
# 2       0_1518 2022-08-20 13:21:29.043970   s_255965     c_103   f   1986
# 3       0_1518 2021-05-09 11:52:55.100386    s_32104    c_6714   f   1968
# 4       0_1518 2022-05-30 01:17:07.487046   s_216118    c_6714   f   1968
# ...        ...                        ...        ...       ...  ..    ...
# 679327  0_2245 2021-10-19 09:32:03.667461   s_107022    c_6128   m   1986
# 679328  0_2245 2021-11-12 09:25:22.905886   s_118458    c_7416   m   1933
# 679329  0_2245 2021-08-22 08:51:27.564509    s_79102    c_6752   m   1987
# 679330  0_2245 2022-04-22 08:51:27.564509   s_197669    c_6752   m   1987
# 679331  0_2245 2021-05-20 07:44:21.415061    s_36985    c_1450   f   1959
#
#         price  categ  transac_year   weekday  month
# 0        4.18      0          2022    Friday      5
# 1        4.18      0          2021   Tuesday      7
# 2        4.18      0          2022  Saturday      8
# 3        4.18      0          2021    Sunday      5
# 4        4.18      0          2022    Monday      5
# ...       ...    ...           ...       ...    ...
# 679327  10.64      0          2021   Tuesday     10
# 679328  10.64      0          2021    Friday     11
# 679329  10.64      0          2021    Sunday      8
# 679330  10.64      0          2022    Friday      4
# 679331  10.64      0          2021  Thursday      5
#
# [679332 rows x 11 columns]

# %%
#Création colonnes age puis intervalle d'âge selon comportement client (panier moyen par age)
rapport['age'] = rapport['transac_year'] - rapport['birth']
print(rapport['age'].min())
print(rapport['age'].max())
# Out:
# 17
# 94

# %%
# Visuel panier moyen rapide mais pas précis 
plt.title('Panier moyen selon les âges')
rapport.groupby('age')['price'].mean().plot()
plt.ylabel('Panier moyen')
# Out:
# Text(0, 0.5, 'Panier moyen')

# %%
# Panier moyen selon l'âge en mieux
ca_age = round(rapport.groupby('age', as_index=False)['price'].mean(),2)
print("panier moyen par âge :")


print(ca_age)

plt.figure(figsize=(19,14))
sns.barplot(data=ca_age, x='age', y='price')
# Out:
# panier moyen par âge :
#     age  price
# 0    17  40.65
# 1    18  39.91
# 2    19  41.03
# 3    20  39.97
# 4    21  39.97
# ..  ...    ...
# 73   90  16.93
# 74   91  16.45
# 75   92  16.89
# 76   93  16.40
# 77   94  19.03
#
# [78 rows x 2 columns]
# <AxesSubplot:xlabel='age', ylabel='price'>

# %% [markdown]
# Les mineurs n'ont pas le droit d'acheter sur Internet avant leur majorité ou sous accord parental, émancipation. On va donc partir du principe que les personnes âgées de 17 ans en ont 18.

# %%
# Création des intervalles d'âge selon les données du graph :
# On a 18-30, 30-50, 50-94 (à couper en 2 car tp grand)
rapport['age'].replace(17, 18, inplace=True) 
rapport["intervalle_age"] = pd.cut(rapport['age'], bins=(18,30,50,70,95), right=False)  #right=False car on veut que le chiffre juste avant 18, 30, etc soit INCLUS
rapport['intervalle_age'].isna().sum() #Vérif tout est ok
# Out:
# 0

# %%
rapport.head()
# Out:
#   id_prod                       date session_id client_id sex  birth  price  \
# 0  0_1518 2022-05-20 13:21:29.043970   s_211425     c_103   f   1986   4.18
# 1  0_1518 2021-07-20 13:21:29.043970    s_64849     c_103   f   1986   4.18
# 2  0_1518 2022-08-20 13:21:29.043970   s_255965     c_103   f   1986   4.18
# 3  0_1518 2021-05-09 11:52:55.100386    s_32104    c_6714   f   1968   4.18
# 4  0_1518 2022-05-30 01:17:07.487046   s_216118    c_6714   f   1968   4.18
#
#    categ  transac_year   weekday  month  age intervalle_age
# 0      0          2022    Friday      5   36       [30, 50)
# 1      0          2021   Tuesday      7   35       [30, 50)
# 2      0          2022  Saturday      8   36       [30, 50)
# 3      0          2021    Sunday      5   53       [50, 70)
# 4      0          2022    Monday      5   54       [50, 70)

# %%
#Enregistrement d'un csv pour le réutiliser sur le prochain notebook 
rapport.to_csv('rapport.csv', index=False)
